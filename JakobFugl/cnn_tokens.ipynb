# %%
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
from torchvision import transforms
from torchvision.models import resnet50, ResNet50_Weights
from sklearn.preprocessing import MinMaxScaler, StandardScaler, FunctionTransformer

scaler = MinMaxScaler()


import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import pandas as pd
import os
import numpy as np

# %%
# Find unique entries
unique_path = r"../data/grand_scraper_folder/unique_scrandle_cases_FULL.csv"
unique_dataframe = pd.read_csv(unique_path)
unique_entries = [unique_dataframe["occurrences"][i].split("|")[0].split(" ")[0] + ".webp" for i in range(len(unique_dataframe["occurrences"]))]

# %%
#Next, we´ll get the low-res photos imported(doesnt take long. for my computer: 7.5s)

#Creating a list for the photos with the corresponding dates and image names as well(crude way of being able to see which are outliers.
#Needs to be done better, really. If someone has the time, feel free to find a better way of doing things)
images_raw = []

#Next, a list for the metadata i want(for now, at least. there´s certainly going to be a better way of doing this later):
metadata_raw = []


#Folder with folders of images:
base_folder = r"../data/scrandle_padded_low_res_data"
#Meta data folders(yes, a bit inefficient. CHANGE LATER):
meta_folder = r"../data/grand_scraper_folder/scrandle_data"
current_folder = None


#Looping over all dates in the listed directory/folder:
for entry in sorted(unique_entries):
    date, image_placement = entry.split(":")
    
    #Finding a new date folder to check
    date_path = os.path.join(base_folder, date)
    meta_date_path = os.path.join(meta_folder, date)
    #Checking if the date path exists
    if not os.path.isdir(date_path):
        continue

    #print(f"Processing {entry}")
    
    #Reading entry image:
    image_path = os.path.join(date_path, image_placement)
    images_raw.append({
                    "date": date,
                    "image_name": image_placement,
                    "RGB": plt.imread(image_path, format="webp"),
                })

    if current_folder != date:
        current_folder = date
        meta_path = os.path.join(meta_folder, date, "meta.csv")
        print(meta_path)
        meta_intermediate = pd.read_csv(meta_path)
        
    entry_row = meta_intermediate.loc[meta_intermediate["image_name"] == image_placement]
    metadata_raw.append({
                "price": entry_row["price"],
                "rating": entry_row["rating"],
                "year": entry_row["year"],
                "date": entry_row["date"],
                "image_name": entry_row["image_name"],
                "title": entry_row["title"],
                "subtitle": entry_row["subtitle"],
                "club": entry_row["club"],
                "country": entry_row["country"],
            })
# Out:
# ../data/grand_scraper_folder/scrandle_data/2025-04-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-04-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-05-31/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-06-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-07-31/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-08-31/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-09-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-10-31/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-11-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2025-12-31/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-01-31/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-02-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-03-31/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-04-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-01/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-02/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-03/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-04/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-05/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-06/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-07/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-08/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-09/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-10/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-11/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-12/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-13/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-14/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-15/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-16/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-17/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-18/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-19/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-20/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-21/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-22/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-23/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-24/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-25/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-26/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-27/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-28/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-29/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-30/meta.csv
# ../data/grand_scraper_folder/scrandle_data/2026-05-31/meta.csv

# %%
ratings = []
for i in range(len(metadata_raw)):
    ratings += metadata_raw[i]["rating"].to_list()
ratings = torch.tensor(ratings) / 100

prices = []
for i in range(len(metadata_raw)):
    prices += metadata_raw[i]["price"].to_list()
prices = np.array(prices)
nan_mask = prices != prices
prices[nan_mask] = 0.0
prices = torch.tensor(scaler.fit_transform(prices.reshape(-1, 1)).ravel())

images = np.stack([img["RGB"] for img in images_raw]).astype(np.float32)
images = torch.from_numpy(images) / 255.0
images = images.permute(0,3,1,2)

# %%
class ImagePriceRatingDataset(Dataset):
    def __init__(self, ratings, images, prices):
        if len(ratings) != len(images) or len(images) != len(prices):
            raise ValueError("ratings, images, and prices must have equal length")
        self.ratings = ratings
        self.images = images
        self.prices = prices

    def __len__(self):
        return len(self.ratings)

    def __getitem__(self, idx):
        return self.images[idx], self.prices[idx], self.ratings[idx]

class ImagePriceModel(nn.Module):
    def __init__(self):
        super().__init__()
        weights = ResNet50_Weights.IMAGENET1K_V2
        cnn = resnet50(weights=weights)
        self.cnn = nn.Sequential(*list(cnn.children())[:-1])  # 2048 features

        self.price_branch = nn.Sequential(
            nn.Linear(1, 1),
            nn.ReLU(),
        )

        self.head = nn.Sequential(
            nn.Linear(2048 + 1, 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 1),
        )

    def forward(self, image, price):
        img_feat = self.cnn(image).flatten(1)      # [B, 2048]
        price_feat = self.price_branch(price)            # [B, 32]
        x = torch.cat([img_feat, price_feat], dim=1)
        return self.head(x)



dataset = ImagePriceRatingDataset(ratings, images, prices)
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(
    dataset, [train_size, test_size], generator=torch.Generator().manual_seed(42)
)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using Device: {device}")

model = ImagePriceModel().to(device)
criterion = nn.L1Loss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# training loop
for epoch in range(10):
    model.train()
    total_loss = 0.0

    for images_loaded, prices_loaded, ratings_loaded in train_loader:
        images_temp = images_loaded.float().to(device)
        prices_temp = prices_loaded.float().unsqueeze(1).to(device)
        ratings_temp = ratings_loaded.float().unsqueeze(1).to(device)

        preds = model(images_temp, prices_temp)
        loss = criterion(preds, ratings_temp)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"epoch {epoch+1}: loss={total_loss/len(train_loader):.4f}")
# Out:
# Using Device: cuda
# epoch 1: loss=0.2111
# epoch 2: loss=0.1695
# epoch 3: loss=0.1618
# epoch 4: loss=0.1487
# epoch 5: loss=0.1404
# epoch 6: loss=0.1312
# epoch 7: loss=0.1253
# epoch 8: loss=0.1220
# epoch 9: loss=0.1202
# epoch 10: loss=0.1077

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# training loop
for epoch in range(10):
    model.train()
    total_loss = 0.0

    for images_loaded, prices_loaded, ratings_loaded in train_loader:
        images_temp = images_loaded.float().to(device)
        prices_temp = prices_loaded.float().unsqueeze(1).to(device)
        ratings_temp = ratings_loaded.float().unsqueeze(1).to(device)

        preds = model(images_temp, prices_temp)
        loss = criterion(preds, ratings_temp)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"epoch {epoch+1}: loss={total_loss/len(train_loader):.4f}")
# Out:
# epoch 1: loss=0.0858
# epoch 2: loss=0.0738
# epoch 3: loss=0.0668
# epoch 4: loss=0.0615
# epoch 5: loss=0.0585
# epoch 6: loss=0.0564

# %%
torch.save(model.state_dict(), "model_weights")

# %%
model.eval()

preds_train = []
trues_train = []

with torch.no_grad():
    for images_loaded, prices_loaded, ratings_loaded in train_loader:
        images_loaded = images_loaded.to(device)
        prices_loaded = prices_loaded.float().unsqueeze(1).to(device)

        outputs = model(images_loaded, prices_loaded).squeeze(1)

        preds_train.append(outputs.cpu())
        trues_train.append(ratings_loaded.cpu())

preds_train = torch.cat(preds_train).numpy()
trues_train = torch.cat(trues_train).numpy()


preds_test = []
trues_test = []

with torch.no_grad():
    for images_loaded, prices_loaded, ratings_loaded in test_loader:
        images_loaded = images_loaded.to(device)
        prices_loaded = prices_loaded.float().unsqueeze(1).to(device)

        outputs = model(images_loaded, prices_loaded).squeeze(1)

        preds_test.append(outputs.cpu())
        trues_test.append(ratings_loaded.cpu())

preds_test = torch.cat(preds_test).numpy()
trues_test = torch.cat(trues_test).numpy()

# %%
mask = trues_train != 0.0
loss_train = np.mean(np.abs(preds_train - trues_train))

fig, ax = plt.subplots(1,2, figsize=(16,7))
ax[0].scatter(trues_train, preds_train)
ax[0].set_xlim(-0.1,1.1)
ax[0].set_ylim(-0.1,1.1)
ax[0].set_xlabel("True", fontsize=22)
ax[0].set_ylabel("Predicted", fontsize=22)
ax[0].set_title(f"Train - 80%: Loss: {loss_train*100:.3f}%", fontsize=26)
ax[0].grid()

mask = trues_test != 0.0
loss_test = np.mean(np.abs(preds_test - trues_test))

ax[1].scatter(trues_test, preds_test)
ax[1].set_xlim(-0.1,1.1)
ax[1].set_ylim(-0.1,1.1)
ax[1].set_xlabel("True", fontsize=22)
ax[1].set_ylabel("Predicted", fontsize=22)
ax[1].set_title(f"Test - 20%: Loss {loss_test*100:.3f}%", fontsize=26)
ax[1].grid()
plt.show()
